# %% [markdown]
# # 2. Importing Packages That Aren't In Snowflake's Anaconda Channel
#
# Now we're going to create and backtest a strategy within Snowpark using our initial data and the ML prediction.
#
# In this lab you will learn how to:
#
# 1. Create a session for Snowpark with Snowflake
# 2. Create a SPROC in Snowflake, and include packages that aren't in Snowflake's Anaconda Channel yet
# 3. Migrate the SPROC to a vectorised UDTF functionality for better scalability
#
# ## Prerequisites:
# Part 1. is assumed to have been fully executed

# %%
import json
import pandas as pd
from snowflake.snowpark.session import Session
from snowflake.snowpark.types import PandasDataFrameType, IntegerType, StringType, FloatType, DateType, Variant
from snowflake.ml._internal.utils import identifier
import backtesting as bt
from backtesting.lib import crossover

# %% [markdown]
# # 2.1 Reading Snowflake Connection Details, create a Session
#
# TODO: Update your json path for your credentials

# %%
snowflake_connection_cfg = json.loads(open("/Users/mitaylor/Documents/creds/creds.json").read()) # <--- Update here
session = Session.builder.configs(snowflake_connection_cfg).create()
session.sql("USE DATABASE HOL_DEMO").collect()
session.sql("CREATE OR REPLACE STAGE YOUR_STAGE").collect()
session.sql("CREATE OR REPLACE WAREHOUSE ASYNC_WH WITH WAREHOUSE_SIZE='MEDIUM' WAREHOUSE_TYPE = 'SNOWPARK-OPTIMIZED'").collect()
# Out:
# [Row(status='Warehouse ASYNC_WH successfully created.')]

# %% [markdown]
# # 2.2.1 Let's run a SPROC
#
# TODO: Just run the cell!

# %%
def hello_world(session: Session) -> Variant:
    return "hello world"

# Register sproc
hello_world_demo = session.sproc.register(
                              func=hello_world, 
                              name='hello_world', 
                              is_permanent=True, 
                              replace=True,
                              stage_location='@YOUR_STAGE', 
                              packages=['snowflake-snowpark-python'])
# Call sproc
hello_world_demo()
# Out:
# '"hello world"'

# %% [markdown]
# # 2.2.2 Trying to Create a SPROC Using the python BACKTEST library
#
# TODO: Just run the cell!

# %%
def sproc_test_backtesting(session: Session) -> Variant:
    import backtesting as bt
    return "It works!"

# Register sproc
sproc_test_backtesting_demo = session.sproc.register(
                              func=sproc_test_backtesting, 
                              name='YOUR_SPROC_NAME', 
                              is_permanent=True, 
                              replace=True,
                              stage_location='@YOUR_STAGE', 
                              packages=['snowflake-snowpark-python', 'backtesting', 'bokeh'])
# Call sproc
sproc_test_backtesting_demo()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 6
#       3     return "It works!"
#       5 # Register sproc
# ----> 6 sproc_test_backtesting_demo = session.sproc.register(
#       7                               func=sproc_test_backtesting,
#       8                               name='YOUR_SPROC_NAME',
#       9                               is_permanent=True,
#      10                               replace=True,
#      11                               stage_location='@YOUR_STAGE',
#      12                               packages=['snowflake-snowpark-python', 'backtesting', 'bokeh'])
#      13 # Call sproc
#      14 sproc_test_backtesting_demo()
#
# File ~/opt/anaconda3/envs/snowpark-ml-hol/lib/python3.11/site-packages/snowflake/snowpark/stored_procedure.py:532, in StoredProcedureRegistration.register(self, func, return_type, input_types, name, is_permanent, stage_location, imports, packages, replace, if_not_exists, parallel, execute_as, strict, external_access_integrations, secrets, statement_params, source_code_display, **kwargs)
#     527 check_register_args(
#     528     TempObjectType.PROCEDURE, name, is_permanent, stage_location, parallel
#     529 )
#     531 # register stored procedure
# --> 532 return self._do_register_sp(
#     533     func,
#     534     return_type,
#     535     input_types,
#     536     name,
#     537     stage_location,
#     538     imports,
#     539     packages,
#     540     replace,
#     541     if_not_exists,
#     542     parallel,
#     543     strict,
#     544     external_access_integrations=external_access_integrations,
#     545     secrets=secrets,
#     546     statement_params=statement_params,
#     547     execute_as=execute_as,
#     548     api_call_source="StoredProcedureRegistration.register",
#     549     source_code_display=source_code_display,
#     550     anonymous=kwargs.get("anonymous", False),
#     551     is_permanent=is_permanent,
#     552     # force_inline_code avoids uploading python file
#     553     # when we know the code is not too large. This is useful
#     554     # in Pandas API to create stored procedures not registered by users.
#     555     force_inline_code=kwargs.get("force_inline_code", False),
#     556 )
#
# File ~/opt/anaconda3/envs/snowpark-ml-hol/lib/python3.11/site-packages/snowflake/snowpark/stored_procedure.py:754, in StoredProcedureRegistration._do_register_sp(self, func, return_type, input_types, sp_name, stage_location, imports, packages, replace, if_not_exists, parallel, strict, source_code_display, statement_params, execute_as, anonymous, api_call_source, skip_upload_on_content_match, is_permanent, external_access_integrations, secrets, force_inline_code)
#     742 arg_names = ["session"] + [f"arg{i+1}" for i in range(len(input_types))]
#     743 input_args = [
#     744     UDFColumn(dt, arg_name) for dt, arg_name in zip(input_types, arg_names[1:])
#     745 ]
#     747 (
#     748     handler,
#     749     code,
#     750     all_imports,
#     751     all_packages,
#     752     upload_file_stage_location,
#     753     custom_python_runtime_version_allowed,
# --> 754 ) = resolve_imports_and_packages(
#     755     self._session,
#     756     TempObjectType.PROCEDURE,
#     757     func,
#     758     arg_names,
#     759     udf_name,
#     760     stage_location,
#     761     imports,
#     762     packages,
#     763     parallel,
#     764     statement_params=statement_params,
#     765     source_code_display=source_code_display,
#     766     skip_upload_on_content_match=skip_upload_on_content_match,
#     767     is_permanent=is_permanent,
#     768     force_inline_code=force_inline_code,
#     769 )
#     771 if not custom_python_runtime_version_allowed:
#     772     check_python_runtime_version(
#     773         self._session._runtime_version_from_requirement
#     774     )
#
# File ~/opt/anaconda3/envs/snowpark-ml-hol/lib/python3.11/site-packages/snowflake/snowpark/_internal/udf_utils.py:826, in resolve_imports_and_packages(session, object_type, func, arg_names, udf_name, stage_location, imports, packages, parallel, is_pandas_udf, is_dataframe_input, max_batch_size, statement_params, source_code_display, skip_upload_on_content_match, is_permanent, force_inline_code)
#     820 upload_and_import_stage = (
#     821     import_only_stage if is_permanent else session.get_session_stage()
#     822 )
#     824 # resolve packages
#     825 resolved_packages = (
# --> 826     session._resolve_packages(packages, include_pandas=is_pandas_udf)
#     827     if packages is not None
#     828     else session._resolve_packages(
#     829         [],
#     830         session._packages,
#     831         validate_package=False,
#     832         include_pandas=is_pandas_udf,
#     833     )
#     834 )
#     836 # resolve imports
#     837 if imports:
#
# File ~/opt/anaconda3/envs/snowpark-ml-hol/lib/python3.11/site-packages/snowflake/snowpark/session.py:1130, in Session._resolve_packages(self, packages, existing_packages_dict, validate_package, include_pandas)
#    1124     raise RuntimeError(
#    1125         f"Cannot add package {package_name}{version_text} because Anaconda terms must be accepted "
#    1126         "by ORGADMIN to use Anaconda 3rd party packages. Please follow the instructions at "
#    1127         "https://docs.snowflake.com/en/developer-guide/udf/python/udf-python-packages.html#using-third-party-packages-from-anaconda."
#    1128     )
#    1129 if not self._custom_package_usage_config.get("enabled", False):
# -> 1130     raise RuntimeError(
#    1131         f"Cannot add package {package_req} because it is not available in Snowflake "
#    1132         f"and Session.custom_package_usage_config['enabled'] is not set to True. To upload these packages, you can "
#    1133         f"set it to True or find the directory of these packages and add it via Session.add_import. See details at "
#    1134         f"https://docs.snowflake.com/en/developer-guide/snowpark/python/creating-udfs.html#using-third-party-packages-from-anaconda-in-a-udf."
#    1135     )
#    1136 unsupported_packages.append(package)
#    1137 continue
#
# RuntimeError: Cannot add package backtesting because it is not available in Snowflake and Session.custom_package_usage_config['enabled'] is not set to True. To upload these packages, you can set it to True or find the directory of these packages and add it via Session.add_import. See details at https://docs.snowflake.com/en/developer-guide/snowpark/python/creating-udfs.html#using-third-party-packages-from-anaconda-in-a-udf.

# %% [markdown]
# Disaster!  Apparently Backtesting isn't available in Snowflake's Anaconda Channel (YET), but not to worry, we have a fix
#
# See here for the full list of available packages https://repo.anaconda.com/pkgs/snowflake/

# %% [markdown]
# # 2.2.3 Trying to Create a SPROC Using the python BACKTEST library
#
# TODO:
#
# 1. Open up your browswer and log in to Snowflake, copy 'wheel_loader.py' and 'Backtesting-0.3.4.dev30+g0ce24d8-py3-none-any.whl' to Your_Stage (Data-> DataBases -> HOL_DEMO -> PUBLIC -> STAGES)
# 2. Run the cell
#
# Note you can do this programmatically with SNOWCLI, but this is an easy way for this demo.  Further reading - https://www.askpython.com/python/examples/wheel-for-python-package if you want to learn how to create a whl file from scratch

# %%
# Define sproc to test that the import was successful
def sproc_test_backtesting(session: Session) -> Variant:
    import wheel_loader
    wheel_loader.load('Backtesting-0.3.4.dev30+g0ce24d8-py3-none-any.whl')
    import pandas as pd
    import backtesting as bt
    return "It works!"

# Register sproc
sproc_test_backtesting_demo = session.sproc.register(
                              func=sproc_test_backtesting, 
                              name='YOUR_SPROC_NAME', 
                              is_permanent=True, 
                              replace=True,
                              stage_location='@YOUR_STAGE', 
                              packages=['snowflake-snowpark-python', 'bokeh'], # Needed as dependency
                              imports=["@YOUR_STAGE/wheel_loader.py",
                                       "@YOUR_STAGE/Backtesting-0.3.4.dev30+g0ce24d8-py3-none-any.whl"])
# Call sproc
sproc_test_backtesting_demo()

# %% [markdown]
# # 2.2.4 Using the Backtest library locally
#
# TODO: Optional - update the Strategy as you see fit

# %%
# Create Strategy
def MovingAverage(closes:pd.Series, n:int) -> pd.Series:
    return pd.Series(closes).rolling(n).mean()

class SmaCross(bt.Strategy):
    sma_fast = 12 
    sma_slow = 35
    
    def init(self):
        self.sma1 = self.I(MovingAverage, self.data.Close, self.sma_fast)
        self.sma2 = self.I(MovingAverage, self.data.Close, self.sma_slow)

    def next(self):
        if not self.position and crossover(self.sma1, self.sma2) and crossover(self.data.CLOSE_PREDICT,self.sma2):
            self.buy()
        elif self.position and crossover(self.sma2, self.sma1):
            self.position.close()

# Run backtest
data = session.sql("""SELECT * FROM ML_PREDICT WHERE SYMBOL = 'IBM'""").to_pandas()
data.columns = ['DATE', 'Open', 'High', 'Low', 'Close', 'SYMBOL', 'CLOSE_M1', 'CLOSE_M2', 'CLOSE_M3', 'CLOSE_M4', 'CLOSE_M5', 'CLOSE_PREDICT']
btest = bt.Backtest(data, SmaCross, cash=10_000, commission=0,exclusive_orders=True)
stats = btest.run()[:-3]
df = pd.DataFrame(stats).T
df['Strategy_Name'] = "SMA_CROSS"
df
# Out:
# /var/folders/97/8vc6xcbx4zd06p75xg9frdrw0000gn/T/ipykernel_38360/822704722.py:24: UserWarning: Data index is not datetime. Assuming simple periods, but `pd.DateTimeIndex` is advised.
#   btest = bt.Backtest(data, SmaCross, cash=10_000, commission=0,exclusive_orders=True)
#   Start    End Duration Exposure Time [%] Equity Final [$] Equity Peak [$]  \
# 0   0.0  500.0    500.0         50.698603       506.678909    11808.079437
#
#   Return [%] Buy & Hold Return [%] Return (Ann.) [%] Volatility (Ann.) [%]  \
# 0 -94.933211             -14.36669               0.0                   NaN
#
#    ... Win Rate [%] Best Trade [%] Worst Trade [%] Avg. Trade [%]  \
# 0  ...    31.707317      22.359846      -27.126088      -7.395738
#
#   Max. Trade Duration Avg. Trade Duration Profit Factor Expectancy [%]  \
# 0                12.0            5.195122      0.339571      -6.369701
#
#         SQN Strategy_Name
# 0 -2.320393     SMA_CROSS
#
# [1 rows x 28 columns]

# %% [markdown]
# # 2.2.5 Putting it all together
#
# TODO: Update the SPROC with a Strategy
#
# hints:
# 1. This should be a copy and paste exercise, don't over think it
# 2. writing to a table from pandas looks like this session.write_pandas(df, table_name='BACKTEST_RESULTS', auto_create_table=True)

# %%
def sproc_test_backtesting(session: Session, symbol:str, target_table:str) -> Variant:
    import wheel_loader
    wheel_loader.load('Backtesting-0.3.4.dev30+g0ce24d8-py3-none-any.whl')


    ### This will be blank in the session ###
    import pandas as pd
    import backtesting as bt
    from backtesting.lib import crossover
    import pandas as pd
    
    def MovingAverage(closes:pd.Series, n:int) -> pd.Series:
        return pd.Series(closes).rolling(n).mean()
    
    class SmaCross(bt.Strategy):
        sma_fast = 12 
        sma_slow = 35
        
        def init(self):
            self.sma1 = self.I(MovingAverage, self.data.Close, self.sma_fast)
            self.sma2 = self.I(MovingAverage, self.data.Close, self.sma_slow)
    
        def next(self):
            if not self.position and crossover(self.sma1, self.sma2) and crossover(self.data.CLOSE_PREDICT,self.sma2): # if you have a position, and sma1 and sma2 crossover
                self.buy()
            elif self.position and crossover(self.sma2, self.sma1):
                self.position.close()
                
    data = session.sql(f"""SELECT * FROM ML_PREDICT WHERE SYMBOL = '{symbol}'""").to_pandas()
    data.columns = ['DATE', 'Open', 'High', 'Low', 'Close', 'SYMBOL', 'CLOSE_M1', 'CLOSE_M2', 'CLOSE_M3', 'CLOSE_M4', 'CLOSE_M5', 'CLOSE_PREDICT']
    btest = bt.Backtest(data, SmaCross, cash=10_000, commission=0,exclusive_orders=True)
    stats = btest.run()[:-3]
    df = pd.DataFrame(stats).T
    df['Strategy_Name'] = "SMA_CROSS"
    session.write_pandas(df, table_name=target_table, auto_create_table=True)

    ### Up to here ###

# Register sproc
sproc_test_backtesting_demo = session.sproc.register(
                              func=sproc_test_backtesting, 
                              name='YOUR_SPROC_NAME', 
                              is_permanent=True, 
                              replace=True,
                              stage_location='@YOUR_STAGE', 
                              packages=['snowflake-snowpark-python', 'bokeh'], # Needed as dependency
                              imports=["@YOUR_STAGE/wheel_loader.py",
                                       "@YOUR_STAGE/Backtesting-0.3.4.dev30+g0ce24d8-py3-none-any.whl"])
# Call sproc
sproc_test_backtesting_demo("IBM", "SPROC_BT_TEST")
session.table('SPROC_BT_TEST').limit(5).to_pandas()
# Out:
#    Start    End  Duration  Exposure Time [%]  Equity Final [$]  \
# 0    0.0  500.0     500.0          50.698603        506.678909
# 1    0.0  500.0     500.0          50.698603        506.678909
# 2    0.0  500.0     500.0          50.698603        506.678909
#
#    Equity Peak [$]  Return [%]  Buy & Hold Return [%]  Return (Ann.) [%]  \
# 0     11808.079437  -94.933211              -14.36669                0.0
# 1     11808.079437  -94.933211              -14.36669                0.0
# 2     11808.079437  -94.933211              -14.36669                0.0
#
#    Volatility (Ann.) [%]  ...  Best Trade [%]  Worst Trade [%]  \
# 0                    NaN  ...       22.359846       -27.126088
# 1                    NaN  ...       22.359846       -27.126088
# 2                    NaN  ...       22.359846       -27.126088
#
#    Avg. Trade [%]  Max. Trade Duration  Avg. Trade Duration  Profit Factor  \
# 0       -7.395738                 12.0             5.195122       0.339571
# 1       -7.395738                 12.0             5.195122       0.339571
# 2       -7.395738                 12.0             5.195122       0.339571
#
#    Expectancy [%]       SQN  Kelly Criterion  Strategy_Name
# 0       -6.369701 -2.320393        -0.838308      SMA_CROSS
# 1       -6.369701 -2.320393        -0.838308      SMA_CROSS
# 2       -6.369701 -2.320393        -0.838308      SMA_CROSS
#
# [3 rows x 29 columns]

# %% [markdown]
# # 2.3 Parallelise with a UDTF
#
# TODO: Update the UDTF with code that mirrors the SPROC above

# %%
class Strat_Backtest:
    def end_partition(self, data):
        data.columns = ['DATE', 'Open', 'High', 'Low', 'Close', 'SYMBOL', 'CLOSE_PREDICT']

        ### This will be blank in the session ###

        import wheel_loader
        wheel_loader.load('Backtesting-0.3.4.dev30+g0ce24d8-py3-none-any.whl')
        import pandas as pd
        import backtesting as bt
        from backtesting.lib import crossover
        import pandas as pd
        def MovingAverage(closes:pd.Series, n:int) -> pd.Series:
            return pd.Series(closes).rolling(n).mean()
        
        class SmaCross(bt.Strategy):
            sma_fast = 12 
            sma_slow = 35
            
            def init(self):
                self.sma1 = self.I(MovingAverage, self.data.Close, self.sma_fast)
                self.sma2 = self.I(MovingAverage, self.data.Close, self.sma_slow)
        
            def next(self):
                if not self.position and crossover(self.sma1, self.sma2) and crossover(self.data.CLOSE_PREDICT,self.sma2): # if you have a position, and sma1 and sma2 crossover
                    self.buy()
                elif self.position and crossover(self.sma2, self.sma1):
                    self.position.close()
                    
        btest = bt.Backtest(data, SmaCross, cash=10_000, commission=0,exclusive_orders=True)
        stats = btest.run()[:-3]
        df_stats = pd.DataFrame(stats).T
        df_stats['Strategy_Name'] = "SMA_CROSS"
        ### Up to here ###

        yield df_stats # note instead of writing to a table as you do in a stored procedure, in a UDTF you return a pandas dataframe (see the next line) which gets combined into a snowpark dataframe

# Register UDTF
Strat_Backtest.end_partition._sf_vectorized_input = pd.DataFrame
strat_bt_udtf = session.udtf.register(
    Strat_Backtest, # the class
    input_types=[PandasDataFrameType([DateType(), FloatType(),FloatType(),FloatType(),FloatType(),StringType(), FloatType()])],
    output_schema=PandasDataFrameType([FloatType()]*28+[StringType()],
                                      ["ST", "End_", 'Duration', 'Exposure_Time_pct', 'Equity_Final_USD',
                                       'Equity_Peak_USD', 'Return_pct', 'Buy_and_Hold_Return_pct',
                                       'Return_Ann_pct', 'Volatility_Ann_pct', 'Sharpe_Ratio',
                                       'Sortino_Ratio', 'Calmar_Ratio', 'Max_Drawdown_pct',
                                       'Avg_Drawdown_pct', 'Max_Drawdown_Duration', 'Avg_Drawdown_Duration',
                                       'Num_Trades', 'Win_Rate_pct', 'Best_Trade_pct', 'Worst_Trade_pct',
                                       'Avg_Trade_pct', 'Max_Trade_Duration', 'Avg_Trade_Duration',
                                       'Profit_Factor', 'Expectancy_pct', 'SQN', "Kelly_Criterion","STRAT"]),
                              stage_location='@YOUR_STAGE', 
                              packages=['snowflake-snowpark-python', 'bokeh'], # Needed as dependency
                              imports=["@YOUR_STAGE/wheel_loader.py",
                                       "@YOUR_STAGE/Backtesting-0.3.4.dev30+g0ce24d8-py3-none-any.whl"])

# %%
sdf = session.table("ML_PREDICT")
sdf_prepped = sdf.select(strat_bt_udtf(*['DATE', 'Open', 'High', 'Low', 'Close', 'SYMBOL', 'CLOSE_PREDICT']).over(partition_by=['SYMBOL']))
sdf_prepped.limit(5).to_pandas()
# Out:
#     ST   END_  DURATION  EXPOSURE_TIME_PCT  EQUITY_FINAL_USD  EQUITY_PEAK_USD  \
# 0  0.0  500.0     500.0           5.788423        7887.22049     10537.039795
#
#    RETURN_PCT  BUY_AND_HOLD_RETURN_PCT  RETURN_ANN_PCT  VOLATILITY_ANN_PCT  \
# 0  -21.127795                 2.844457             0.0                 NaN
#
#    ...  BEST_TRADE_PCT  WORST_TRADE_PCT  AVG_TRADE_PCT  MAX_TRADE_DURATION  \
# 0  ...        18.35668       -17.487842      -3.371015                 8.0
#
#    AVG_TRADE_DURATION  PROFIT_FACTOR  EXPECTANCY_PCT       SQN  \
# 0            3.142857       0.592964       -2.653239 -0.679347
#
#    KELLY_CRITERION      STRAT
# 0        -0.394008  SMA_CROSS
#
# [1 rows x 29 columns]

# %%
sdf_prepped.write.save_as_table("UDTF_BT_TEST", mode="overwrite")

# %% [markdown]
# # Appendix

# %%
bt.plot(filename = "test.html", open_browser=False)
# Out:
# BokehDeprecationWarning: Passing lists of formats for DatetimeTickFormatter scales was deprecated in Bokeh 3.0. Configure a single string format for each scale
# /Users/mitaylor/opt/anaconda3/envs/snowpark_gis/lib/python3.8/site-packages/backtesting/_plotting.py:250: UserWarning: DatetimeFormatter scales now only accept a single format. Using the first provided: '%d %b'
#   formatter=DatetimeTickFormatter(days=['%d %b', '%a %d'],
# BokehDeprecationWarning: Passing lists of formats for DatetimeTickFormatter scales was deprecated in Bokeh 3.0. Configure a single string format for each scale
# /Users/mitaylor/opt/anaconda3/envs/snowpark_gis/lib/python3.8/site-packages/backtesting/_plotting.py:250: UserWarning: DatetimeFormatter scales now only accept a single format. Using the first provided: '%m/%Y'
#   formatter=DatetimeTickFormatter(days=['%d %b', '%a %d'],
# GridPlot(id='p3719', ...)

# %% [markdown]
# UDTF
# Contains the strategy
# Gets the data (from SF, based on input criteria)
# partitions over symbol
# Runs backtest on symbol
